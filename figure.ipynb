# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import Select
import time
import numpy as np
import pyodbc
import pandas as pd
import string
import calendar
import random
from sqlalchemy import create_engine
import urllib

# %%
def get_JAN_amiami():
    figures = []
    driver = webdriver.Chrome()
    driver.get("https://www.amiami.com")
    time.sleep(2)
    assert "AmiAmi" in driver.title
    time.sleep(2)
    menu = driver.find_element(By.ID, 'mega-dropdown')
    time.sleep(0.25)
    menu_items = driver.find_elements(By.CLASS_NAME, 'mega-dropdown-menu__list__list-item')
    time.sleep(0.25)
    figures_home = None
    for m in menu_items:
        if 'Figures' in m.text:
            m.click()
            sub_list = m.find_element(By.ID, 'mega-dropdown-menu-category01')
            sub_categories = sub_list.find_elements(By.TAG_NAME, 'li')
            for s in sub_categories:
                if 'Bishoujo Figures' in s.text:
                    figures_home = s
                    break;
    figures_home.click()
    time.sleep(2)
    newly_added = driver.find_element(By.CLASS_NAME, 'newly-added-items__list')
    figure_links = newly_added.find_elements(By.TAG_NAME, 'a') 
    links = []
    for f in figure_links:
        links.append(f.get_attribute('href'))
    for l in links:
        figure = []
        driver.get(l)
        time.sleep(3)
        figure_title = driver.find_element(By.CLASS_NAME, 'item-detail__section-title')
        figure.append(figure_title.text)
        jp_price = driver.find_element(By.CLASS_NAME, 'item-detail__price_selling-price')
        figure.append(jp_price.text)
        currency_price = driver.find_element(By.CLASS_NAME, 'item-detail__currency')
        local_price = (currency_price.text.split('\n')[0])
        figure.append(local_price.replace('(appx. ', ''))
        about_all = driver.find_elements(By.CLASS_NAME, 'item-about__data')
        for a in about_all:
            if 'JAN code' in a.text:
                figure.append(a.text.split('JAN code')[1].strip())
        driver.back()
        time.sleep(2)
        print(figure)
        figures.append(figure)
    driver.close()

get_JAN_amiami()
# Out:
# ['Arknights Ceobe Pajama Party Ver. Complete Figure(Pre-order)', '5,640JPY', '39.88', '6972228190556']
# ['My Teen Romantic Comedy SNAFU Yukino Yukinoshita Light Novel Vol.6 Cover Illustration Ver. 1/6 Complete Figure(Pre-order)', '19,600JPY', '138.58', '4580416949040']
# ['Asteroid Series Honkai Impact 3rd Elysia Herrscher of Human: Ego Complete Figure(Released)', '6,610JPY', '46.73', '6976068148975']
# ['[Bonus] Azur Lane Shokaku The Crane that Dances With the Wind Ver. 1/7 Complete Figure(Released)', '18,400JPY', '130.09', '6971995421382']
# ['Persona 5: Dancing in Starlight Ann Takamaki Corset Dress ver. 1/6 Complete Figure(Released)', '21,300JPY', '150.60', '4582292602958']
# ['EveD Series AMBRA-02 (Strike Cat) Ambra 1/12 Complete Action Figure(Pre-order)', '7,620JPY', '53.88', '4902273504475']
# ['[Bonus] GRANBLUE FANTASY Vira Oath-Sworn Evening Gown Ver. 1/7 Complete Figure(Provisional Pre-order)', '23,200JPY', '164.03', '6971995421702']
# ['DFORM+ Rascal Does Not Dream Series Mai Sakurajima Deforme Action Figure(Pre-order)', '3,135JPY', '22.17', '4582705280902']
# ['Identity V First Press Limited Edition Box Truth & Inference Redheaded Witch Priestess - "Scarlet" Figure(Provisional Pre-order)', '16,800JPY', '118.78', '']
# ['[Exclusive Sale] Vertex Originals Dark Elf Village 3rd Villager Mercedes 1/6 Complete Figure Antenna Shop Limited Edition 1/6 Figure(Pre-order)', '28,600JPY', '202.21', '4562389471926']
# ['Vertex Originals Dark Elf Village 3rd Villager Mercedes 1/6 Complete Figure(Pre-order)', '24,300JPY', '171.81', '4562389471919']
# ['MODEROID Hatsune Miku GT Project Racing Miku 2022Ver. Plastic Model(Released)', '6,630JPY', '46.88', '4580590181267']
# ['chitocerium VI-carbonia graphites 1/1 Plastic Model(Released)', '6,220JPY', '43.98', '4580590182776']
# ['[Exclusive Sale] Toaru Kagaku no Railgun T Kuroko Shirai Bunny Ver.2nd 1/4 Complete Figure(Released)', '38,500JPY', '272.21', '4570001512056']
# ['Karakai Jouzu no Takagi-san 3 Takagi-san One-piece Dress Ver. 1/6 Complete Figure(Released)', '13,100JPY', '92.62', '4560308575908']
# ['[Exclusive Sale] B-style Ayakashi Triangle Suzu Kanade Bunny Ver. 1/4 Complete Figure(Released)', '38,500JPY', '272.21', '4570001512049']
# ['LookUp Movie "Sailor Moon Cosmos" Eternal Sailor Mercury Complete Figure(Released)', '4,200JPY', '29.70', '4535123835988']
# ['LookUp Movie "Sailor Moon Cosmos" Eternal Sailor Mars Complete Figure(Released)', '4,200JPY', '29.70', '4535123835995']
# ['LookUp Made in Abyss The Golden City of the Scorching Sun Nanachi Complete Figure(Released)', '4,670JPY', '33.02', '4535123837609']
# ['[Exclusive Sale] Re:ZERO -Starting Life in Another World- Rem 1/7 Complete Figure(Released)', '25,850JPY', '182.77', '4562177700603']
# ['[Exclusive Sale] A-Z: [A] 1/7 Complete Figure(Released)', '38,225JPY', '270.26', '4562177700627']
# ['FAIRY TAIL Erza Scarlet the Knight ver. Refine 2022 1/6 Complete Figure(Released)', '24,000JPY', '169.69', '4560321854394']
# ['Animester Little Demon Lilith 1/6 Complete Figure(Released)', '4,740JPY', '33.51', '6971651925902']
# ['Rent-A-Girlfriend Chizuru Mizuhara See-through Lingerie Figure 1/6 Complete Figure(Released)', '25,080JPY', '177.32', '4570000500122']
# ["Nendoroid Kaguya-sama: Love Is War -The Geniuses' War of Love and Brains- Kaguya Shinomiya(Released)", '5,080JPY', '35.92', '4571324598918']
# ["Nendoroid Kaguya-sama: Love Is War -The Geniuses' War of Love and Brains- Chika Fujiwara(Released)", '5,540JPY', '39.17', '4571324598925']
# ['[Exclusive Sale] [AmiAmi Exclusive Bonus] Arknights Schwarz Elite 2 Ver. 1/7 Complete Figure(Released)(Single Shipment)', '45,980JPY', '325.09', '4560228206685']
# ['Character Vocal Series 01 Hatsune Miku 15th Anniversary Ver. 1/7 Complete Figure(Released)(Single Shipment)', '35,900JPY', '253.82', '4580416946124']
# ['Rei Ayanami Rebuild of Evangelion Long Hair Ver. 1/7 Complete Figure(Released)', '22,240JPY', '157.24', '4580416946247']
# ['A-Z: [F01] 1/7 Complete Figure(Released)', '26,130JPY', '184.75', '4582540800044']
# ['Umamusume Pretty Derby The Will to Overtake Satono Diamond 1/7 Complete Figure(Pre-order)', '25,300JPY', '178.88', '4934054041206']
# ['Overlord Albedo Pure White Santa Ver. 1/8 Complete Figure(Pre-order)(Single Shipment)', '34,270JPY', '242.30', '4560228207118']
# ['Overlord Narberal Gamma so-bin Ver. 1/8 Complete Figure(Pre-order)', '21,730JPY', '153.64', '4560228207446']
# ['Nachoneko 1/7 Scale Figure(Pre-order)', '19,800JPY', '139.99', '4582655077645']
# ["Girls' Frontline G11 Mind Eraser 1/7 Scale PVC Figure Ver.(Pre-order)", '27,690JPY', '195.78', '4573451878857']
# ['Nendoroid NEEDY STREAMER OVERLOAD OMGkawaiiAngel-chan(Released)', '5,710JPY', '40.37', '4580590175556']
# ['PLAMAX MF-80 minimum factory Gunbuster Noriko Takaya with Gunbuster Character Color Ver.(Released)', '3,550JPY', '25.10', '4545784013571']
# ['Figuarts mini Fiona Frost "Spy x Family"(Released)', '2,430JPY', '17.18', '4573102654670']
# ['G.E.M. Series ONE PIECE Uta RUN!RUN!RUN! Complete Figure(Released)', '6,350JPY', '44.90', '4535123836893']
# ['S.H.Figuarts Noir "SYNDUALITY Noir"(Released)', '8,500JPY', '60.10', '4573102657473']
# ['[Exclusive Sale] figma FALSLANDER SAMURAI(Pre-order)', '11,000JPY', '77.77', '4545784069271']
# ['Azur Lane Chen Hai 1/7 Complete Figure(Pre-order)', '21,780JPY', '153.99', '4580416949101']
# ['Blue Archive Karin Kakudate (Bunny Girl) Game Playing Ver. 1/7 Complete Figure(Pre-order)', '21,780JPY', '153.99', '4580416949033']
# ['Goddess of Victory: Nikke Anis 1/4 Complete Figure(Pre-order)', '43,560JPY', '307.98', '4570001512551']
# ['Toridamono Original Mira 1/7 Complete Figure(Pre-order)', '19,900JPY', '140.70', '4580522750196']
# ['Anime "Bastard!! -Heavy Metal, Dark Fantasy-" Arshes Nei Complete Figure(Pre-order)', '25,390JPY', '179.51', '4589642715252']
# ['necomi Illustration "One more cup of Vacation" Complete Figure(Pre-order)', '20,270JPY', '143.31', '4589642714934']
# ['VIVIgnette Gunbuster Noriko Takaya [35th Anniversary Ver.] Complete Figure(Pre-order)', '25,300JPY', '178.88', '4934569987044']
# ['To Love-Ru Darkness Golden Darkness Nurse Ver. 1/7 Complete Figure(Pre-order)', '18,600JPY', '131.51', '4560228207422']

# %%
def amiami_lookup(jan):
    figures = []
    driver = webdriver.Chrome()
    driver.get("https://www.amiami.com")
    time.sleep(2)
    assert "AmiAmi" in driver.title
    time.sleep(2)
    searchBar = driver.find_element(By.ID, 'searchBoxInput')
    searchButton = driver.find_element(By.CLASS_NAME, 'search-box__button')
    searchBar.send_keys(jan)
    time.sleep(0.25)
    searchButton.click()
    time.sleep(5)

    results = driver.find_element(By.CLASS_NAME, 'new-items__inner')
    figure_links = results.find_elements(By.TAG_NAME, 'a') 
    links = []
    for f in figure_links:
        links.append(f.get_attribute('href'))
    for l in links:
        figure = []
        driver.get(l)
        time.sleep(3)
        figure_title = driver.find_element(By.CLASS_NAME, 'item-detail__section-title')
        figure.append(figure_title.text)
        jp_price = driver.find_element(By.CLASS_NAME, 'item-detail__price_selling-price')
        figure.append(jp_price.text)
        currency_price = driver.find_element(By.CLASS_NAME, 'item-detail__currency')
        local_price = (currency_price.text.split('\n')[0])
        figure.append(local_price.replace('(appx. ', ''))
        about_all = driver.find_elements(By.CLASS_NAME, 'item-about__data')
        for a in about_all:
            if 'JAN code' in a.text:
                figure.append(a.text.split('JAN code')[1].strip())
        driver.back()
        time.sleep(2)
        print(figure)
        figures.append(figure)
    driver.close()

amiami_lookup('4595123918180')
# Out:
# ['[AmiAmi Exclusive Bonus] [Exclusive Sale] Azur Lane Roon Muse 1/6 Complete Figure AmiAmi Limited Edition(Pre-order)', '28,050JPY', '198.32', '4595123918180']
# ['[Exclusive Sale] Azur Lane Roon Muse 1/6 Complete Figure AmiAmi Limited Edition(Pre-order)', '25,240JPY', '178.45', '4595123918180']
